# %% [markdown]
# # Import Rules Notebook

# %%
# %run ./Rules.ipynb

# %% [markdown]
# # Import Dependencies

# %%
import findspark
findspark.init()
import pyspark # only run after findspark.init()
from pyspark.sql.functions import *
from pyspark.sql.functions import col, explode,coalesce,udf,pandas_udf
from pyspark.sql import SparkSession
from pyspark.sql.types import LongType,StructType,StringType,ArrayType
spark = SparkSession.builder.config('spark.jars','D:\\Programs\\Spark\\spark-2.4.3-bin-hadoop2.7\\jars\\spark-avro_2.11-2.4.5.jar').getOrCreate()
import datetime
from datetime import timedelta 
from pyspark.sql.functions import split
from pyspark.sql import functions
from pyspark.sql.window import *
import pandas as pd
import json

# %%
pd.set_option('display.max_colwidth',-1)

# %% [markdown]
# # Initialise Paths for you Input/Output Directories,Log and DQ Bible

# %%
DQDatasetPath = "datasets"
DQSrc = f"{DQDatasetPath}/Source"
DQSucc = f"{DQDatasetPath}/Success"
DQRej = f"{DQDatasetPath}/Rejects"
DQBible=  f"{DQDatasetPath}/Bible"
AuditLogs = f"{DQDatasetPath}/AuditLogs"
DQLogs = f"{DQDatasetPath}/DQLogs"

# %% [markdown]
# # Record Start Time for the Job

# %%
start_time = str(datetime.datetime.now())
print(start_time)
# Out:
# 2021-05-07 23:12:35.843471

# %% [markdown]
# # Load Employee Data and Display

# %%
src_data =  spark.read.option("header",True).csv(f"{DQSrc}/employee100.csv")
src_data.toPandas()
# Out:
#       id  first_name  last_name                           email  gender  \
# 0    1    Fayth       Paddock    fpaddock0@nytimes.com           Female
# 1    2    Ogden       Ander      oander1@w3.org                  Female
# 2    3    Ludovico    Defew      ldefew2@github.io               Male
# 3    4    Ambrosius   Menlow     amenlow3@weather.com            Male
# 4    5    Inglebert   Barrasse   ibarrasse4@soup.io              Male
# ..  ..          ...        ...                  ...               ...
# 96   97   Huntington  Sherrocks  hsherrocks2o@jalbum.net         ale
# 97   98   Randell     Brister    rbrister2p@dagondesign          Male
# 98   99   Hamnet      Rowbotham  hrowbotham2q@timesonline.co.uk  Female
# 99   100  Derrick     Lunge      dlunge2r@ovh.net                e
# 100  101  Mellisa     Dils       mdils2s@google.com.br           Female
#
#           ip_address emp_join_date     emp_country
# 0    95.152.83.222    2020/09/15    China
# 1    79.153.96.224    2020/10/15    United States
# 2    44.72.101.250    2020/05/23    Peru
# 3    66.138.160.23    2021/04/11    China
# 4    180.85.153.228   2020/08/03    Indonesia
# ..              ...          ...          ...
# 96   94.186.119.255   2019/12/16    Bangladesh
# 97   166.154.213.220  2020/10/15    Philippines
# 98   121.121.36       2021/01/19    Ethiopia
# 99   204.134.255      2021/01/23    Indonesia
# 100  198.149.175.144  2021/04/04    Czech Republic
#
# [101 rows x 8 columns]

# %% [markdown]
# # Read and Display DQ Bible

# %%
dq_rule_bible = spark.read.option("header",True).csv(f"{DQBible}/bible101.csv")
bible_pandas = dq_rule_bible.toPandas()
display(bible_pandas)
# Out:
#   RULE_ID ACTIVE PRIORITY  \
# 0  R001    Y      1
# 1  R002    Y      2
# 2  R003    Y      3
# 3  R004    Y      4
# 4  R005    Y      5
#
#                                                                                                                                                                                                                                       DESCRIPTION  \
# 0  Trims Employee IP address and Soft Fail Record in case of invalid IP else it’s a PASS.The trimmed input column is returned as modified column value in case of PASS else return Original Value
# 1  Trims Emp Join Date and Reject/Hard Fail in case date is not in YYYY/MM/DD format else it’s a pass.The trimmed input column is returned as modified column value in case of PASS else return original value
# 2  Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.
# 3  Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value
# 4  Concatenate Emp_ with Employee id
#
#     TYPE     OUTPUT_COL
# 0  SOFT   ip_address
# 1  HARD   emp_join_date
# 2  SOFT   gender
# 3  HARD   email
# 4  TRANS  emp_sor_id

# %% [markdown]
# # Filter Active DQ Rules

# %%
dq_rule_bible_actv = dq_rule_bible.filter(col("Active") == "Y")
dq_rule_bible_actv.toPandas()
# Out:
#   RULE_ID ACTIVE PRIORITY  \
# 0  R001    Y      1
# 1  R002    Y      2
# 2  R003    Y      3
# 3  R004    Y      4
# 4  R005    Y      5
#
#                                                                                                                                                                                                                                       DESCRIPTION  \
# 0  Trims Employee IP address and Soft Fail Record in case of invalid IP else it’s a PASS.The trimmed input column is returned as modified column value in case of PASS else return Original Value
# 1  Trims Emp Join Date and Reject/Hard Fail in case date is not in YYYY/MM/DD format else it’s a pass.The trimmed input column is returned as modified column value in case of PASS else return original value
# 2  Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.
# 3  Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value
# 4  Concatenate Emp_ with Employee id
#
#     TYPE     OUTPUT_COL
# 0  SOFT   ip_address
# 1  HARD   emp_join_date
# 2  SOFT   gender
# 3  HARD   email
# 4  TRANS  emp_sor_id

# %% [markdown]
# # Collect Active Rules as List of Tuples ad sort on Priority

# %%
actv_rule_to_rdd = dq_rule_bible_actv.repartition(1).orderBy(asc("PRIORITY")).toJSON().collect()
actv_rule_to_list = [json.loads(jsonString) for jsonString in actv_rule_to_rdd ]
print(actv_rule_to_rdd)
# Out:
# ['{"RULE_ID":"R001","ACTIVE":"Y","PRIORITY":"1","DESCRIPTION":"Trims Employee IP address and Soft Fail Record in case of invalid IP else it’s a PASS.The trimmed input column is returned as modified column value in case of PASS else return Original Value","TYPE":"SOFT","OUTPUT_COL":"ip_address"}', '{"RULE_ID":"R002","ACTIVE":"Y","PRIORITY":"2","DESCRIPTION":"Trims Emp Join Date and Reject/Hard Fail in case date is not in YYYY/MM/DD format else it’s a pass.The trimmed input column is returned as modified column value in case of PASS else return original value","TYPE":"HARD","OUTPUT_COL":"emp_join_date"}', '{"RULE_ID":"R003","ACTIVE":"Y","PRIORITY":"3","DESCRIPTION":"Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.","TYPE":"SOFT","OUTPUT_COL":"gender"}', '{"RULE_ID":"R004","ACTIVE":"Y","PRIORITY":"4","DESCRIPTION":"Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value","TYPE":"HARD","OUTPUT_COL":"email"}', '{"RULE_ID":"R005","ACTIVE":"Y","PRIORITY":"5","DESCRIPTION":"Concatenate Emp_ with Employee id","TYPE":"TRANS","OUTPUT_COL":"emp_sor_id"}']

# %% [markdown]
# # Create Target Dataframe after applying Data Quality Rules & display Data Quality Rules and Display Resultant DF

# %%
resultantDF = src_data
# Iterate list of Dictionaries to invoke all rules 1 by 1
for ruleRec in actv_rule_to_list:
    # Store RuleID,OutputColumnName and RuleType
    ruleID,output_col_name,rule_categ = (ruleRec['RULE_ID'],ruleRec['OUTPUT_COL'],ruleRec['TYPE'])
    if rule_categ == "TRANS":
        # If Rule is a transformation,invoke the rule by passing only RuleID,Category and retrieve Output Column Name
        resultantDF =  resultantDF.withColumn(output_col_name,RuleEngine.udf_caller(ruleID,rule_categ))
    else:
        # Else if rule is SOFT/FAIL rule invoke the UDF by only passing RuleID,Category and retrieving array column which has output field name and rule execution status
        resultantDF = resultantDF.withColumn("RuleExecStatus",RuleEngine.udf_caller(ruleID,rule_categ))
        # From array column retrieve output column value and status of the executed rule
        resultantDF = resultantDF.withColumn(ruleID+"_RFLAG",resultantDF['RuleExecStatus'].getItem(1)).withColumn(output_col_name,resultantDF['RuleExecStatus'].getItem(0))

# %%
resultantDF.toPandas()
# Out:
#       id  first_name  last_name                           email  gender  \
# 0    1    Fayth       Paddock    fpaddock0@nytimes.com           Female
# 1    2    Ogden       Ander      oander1@w3.org                  Female
# 2    3    Ludovico    Defew      ldefew2@github.io               Male
# 3    4    Ambrosius   Menlow     amenlow3@weather.com            Male
# 4    5    Inglebert   Barrasse   ibarrasse4@soup.io              Male
# ..  ..          ...        ...                  ...               ...
# 96   97   Huntington  Sherrocks  hsherrocks2o@jalbum.net         ale
# 97   98   Randell     Brister    rbrister2p@dagondesign          Male
# 98   99   Hamnet      Rowbotham  hrowbotham2q@timesonline.co.uk  Female
# 99   100  Derrick     Lunge      dlunge2r@ovh.net                e
# 100  101  Mellisa     Dils       mdils2s@google.com.br           Female
#
#           ip_address emp_join_date     emp_country  \
# 0    95.152.83.222    2020/09/15    China
# 1    79.153.96.224    2020/10/15    United States
# 2    44.72.101.250    2020/05/23    Peru
# 3    66.138.160.23    2021/04/11    China
# 4    180.85.153.228   2020/08/03    Indonesia
# ..              ...          ...          ...
# 96   94.186.119.255   2019/12/16    Bangladesh
# 97   166.154.213.220  2020/10/15    Philippines
# 98   121.121.36       2021/01/19    Ethiopia
# 99   204.134.255      2021/01/23    Indonesia
# 100  198.149.175.144  2021/04/04    Czech Republic
#
#                           RuleExecStatus R001_RFLAG R002_RFLAG R003_RFLAG  \
# 0    [fpaddock0@nytimes.com, ]
# 1    [oander1@w3.org, ]
# 2    [ldefew2@github.io, ]
# 3    [amenlow3@weather.com, ]
# 4    [ibarrasse4@soup.io, ]
# ..                      ...              ..         ..         ..
# 96   [hsherrocks2o@jalbum.net, ]                                SOFT_R003
# 97   [rbrister2p@dagondesign, HARD_R004]
# 98   [hrowbotham2q@timesonline.co.uk, ]
# 99   [dlunge2r@ovh.net, ]                                       SOFT_R003
# 100  [mdils2s@google.com.br, ]
#
#     R004_RFLAG emp_sor_id
# 0               EMP_1
# 1               EMP_2
# 2               EMP_3
# 3               EMP_4
# 4               EMP_5
# ..  ..            ...
# 96              EMP_97
# 97   HARD_R004  EMP_98
# 98              EMP_99
# 99              EMP_100
# 100             EMP_101
#
# [101 rows x 14 columns]

# %% [markdown]
# # Find all Flag Columns from the list containing dictionary of active rules and create a list from the same

# %%
srccols = src_data.columns
RFLAG_ARR = list(
    map(lambda rulerec : json.loads(rulerec)['RULE_ID']+"_RFLAG",
        list(filter(lambda rulerec : (json.loads(rulerec)['TYPE'] != "TRANS"),actv_rule_to_rdd)))
)
    
print(RFLAG_ARR)
# Concat All Flag Columns & check if it contains the string HARD to find all reject records
rulesinglecol = resultantDF.withColumn("ruleflag",concat_ws(",",*RFLAG_ARR))
# Out:
# ['R001_RFLAG', 'R002_RFLAG', 'R003_RFLAG', 'R004_RFLAG']

# %% [markdown]
# # Find Error Rejects

# %%
error_reject_records = rulesinglecol.filter(col("ruleflag").contains("HARD")).drop("ruleflag","RuleExecStatus")
error_reject_records.toPandas()
# Out:
#     id   first_name    last_name                       email  gender  \
# 0   51  Gilburt      Pinnick      gpinnick1e.google.co.uk     Kill
# 1   52  Jobyna       Langmaid     jlangmaid1f                 End
# 2   53  Earle        Ulyet        eulyet1g@slideshare.net     Fem
# 3   54  Sunny        Lindsey      slindsey1h.com.cn           HU
# 4   55  Bobbi        Olliver      bolliver1i@java.com         le
# 5   56  Petronille   Idell        pidell1jshareasale.com      ale
# 6   57  Domeniga     Broose       dbroose1k@people.com.cn     el
# 7   59  Elke         Schollar     ugedomains.com              Female
# 8   60  Briano       Copper       bcopper1nbravesites.com     Male
# 9   61  Lesly        Iltchev      liltchev1o@linkedin.com     H
# 10  62  Arly         Lembrick     alembrick1p.com             Hi
# 11  63  Stevana      MacCosto     smaccosto1qepa.gov          Female
# 12  64  Ramonda      Morison      rmorison1rgoogle.fr         Male
# 13  65  Carrol       Acaster      cacaster1s@sfgate.com       Female
# 14  66  Bret         Sewall       bsewall1tfreewebs.com       Male
# 15  70  Janeen       Uden         shutterfly.com              Female
# 16  71  Steward      Haly         bloomberg.com               Female
# 17  72  Sophey       Ledwidge     sledwidge1znba.com          SWMale
# 18  74  Letti        Leavold      @businessinsider.com        Female
# 19  76  Konstantine  Simonou      ksimonou23twitter.com       Male
# 20  77  Elliot       Roseborough  eroseborough24netscape.com  Male
# 21  78  Nefen        Pelz         npelz25@admin.ch            SW
# 22  79  Cully        Garard       cgarard26@squidoo.com       Male
# 23  81  Marcille     Spenclay     mspenclay28instagram.com    Fale
# 24  85  Romy         Lorenc       rlorenc2c@fotki.com         Female
# 25  86  Ricoriki     Baggs        rbaggs2d@google.com         RTE
# 26  88  Almeta       Gianuzzi     agianuzzi2f-wsj.com         Male
# 27  90  Veda         MacGuiness   vmacguiness2h@51.la         Male
# 28  91  Garek        Kincade      gkincade2i@smh.com.au       Mae
# 29  92  Maryjane     Beange       mbeange2j@admin.ch          Male
# 30  93  Tracey       Swinley      tswinley2knarod.ru          Male
# 31  94  Jacinthe     Gyves        jgyves2ltimesonline.co.uk   Male
# 32  95  Pietro       Heales       pheales2mmicrosoft.com      Female
# 33  96  Hillyer      Blakey       hblakey2ndedecms.com        Female
# 34  98  Randell      Brister      rbrister2p@dagondesign      Male
#
#            ip_address emp_join_date               emp_country R001_RFLAG  \
# 0   253.186.232.9000   2020/51/08    Honduras                  SOFT_R001
# 1   91.5000.172.208    2020/02/51    Ethiopia                  SOFT_R001
# 2   9999.255.188.107   2021/12/33    Japan                     SOFT_R001
# 3   9000.34.248.154    2020/15/29    Portugal                  SOFT_R001
# 4   98.150.137.280     2021/33/28    Russia                    SOFT_R001
# 5   88.252.165.159     2021/01/16    China
# 6   94.190.11.225      2021/33/22    China
# 7   99999.183.233.178  2020/06/16    Russia                    SOFT_R001
# 8   45.213.51.102      2020/87/05    China
# 9   137.212.213.165    2021/71/28    Swaziland
# 10  248.66.113.191     2021/10/09    China
# 11  90.88.8888.189     2021/04/27    Central African Republic  SOFT_R001
# 12  29.40.178.89       2021/04/03    United States
# 13  999978.117.25.218  2020/41/14    Colombia                  SOFT_R001
# 14  99985.9.88.207     2020/01/25    Indonesia                 SOFT_R001
# 15  85.9999.170.98     2020/11/27    Philippines               SOFT_R001
# 16  249.206.235.219    2020/444/15   Kazakhstan
# 17  134.61.81.162      2020/09/03    Armenia
# 18  70.250.183.42      2020/55/17    Indonesia
# 19  171.28.43.63       2021/04/29    Indonesia
# 20  146.194.79.233     2021/55/26    Canada
# 21  38.49.250.184      2020/10/33    Brazil
# 22  108.60.221.45      2020/05/33    Bangladesh
# 23  51.157.16.148      2021/03/03    China
# 24  138.110.215.63     2020/10       Russia
# 25  15.225.202.41      2020/23/24    China
# 26  142.37.27.188      2020/05/24    Peru
# 27  63.10.214          2020/33/30    Japan
# 28  185.234.93.122     2021/87/11    Norway
# 29  3058.40.137        2020/86/02    Philippines               SOFT_R001
# 30  63.84.184.39       2021/33/12    Cameroon
# 31  1868.56.246        2021/01/22    China                     SOFT_R001
# 32  253.93.1111        2020/10/07    China
# 33  128.125.236.223    2020/605      Peru
# 34  166.154.213.220    2020/10/15    Philippines
#
#    R002_RFLAG R003_RFLAG R004_RFLAG emp_sor_id
# 0   HARD_R002  SOFT_R003  HARD_R004  EMP_51
# 1   HARD_R002  SOFT_R003  HARD_R004  EMP_52
# 2   HARD_R002  SOFT_R003             EMP_53
# 3   HARD_R002  SOFT_R003  HARD_R004  EMP_54
# 4   HARD_R002  SOFT_R003             EMP_55
# 5              SOFT_R003  HARD_R004  EMP_56
# 6   HARD_R002  SOFT_R003             EMP_57
# 7                         HARD_R004  EMP_59
# 8   HARD_R002             HARD_R004  EMP_60
# 9   HARD_R002  SOFT_R003             EMP_61
# 10             SOFT_R003  HARD_R004  EMP_62
# 11                        HARD_R004  EMP_63
# 12                        HARD_R004  EMP_64
# 13  HARD_R002                        EMP_65
# 14                        HARD_R004  EMP_66
# 15                        HARD_R004  EMP_70
# 16  HARD_R002             HARD_R004  EMP_71
# 17             SOFT_R003  HARD_R004  EMP_72
# 18  HARD_R002             HARD_R004  EMP_74
# 19                        HARD_R004  EMP_76
# 20  HARD_R002             HARD_R004  EMP_77
# 21  HARD_R002  SOFT_R003             EMP_78
# 22  HARD_R002                        EMP_79
# 23             SOFT_R003  HARD_R004  EMP_81
# 24  HARD_R002                        EMP_85
# 25  HARD_R002  SOFT_R003             EMP_86
# 26                        HARD_R004  EMP_88
# 27  HARD_R002                        EMP_90
# 28  HARD_R002  SOFT_R003             EMP_91
# 29  HARD_R002                        EMP_92
# 30  HARD_R002             HARD_R004  EMP_93
# 31                        HARD_R004  EMP_94
# 32                        HARD_R004  EMP_95
# 33  HARD_R002             HARD_R004  EMP_96
# 34                        HARD_R004  EMP_98

# %%
error_reject_records.write.option("header",True).format("csv").mode("overwrite").save(DQRej)

# %% [markdown]
# # Find Cleansed/Target Records

# %%
# Find all cleansed/target records by concatenating all FLAG columns and check if it doesnt contain String HARD
passed_records = rulesinglecol.filter(col("ruleflag").contains("HARD") ==  False).drop("ruleflag","RuleExecStatus")
passed_records.toPandas()
# Out:
#      id  first_name  last_name                           email  gender  \
# 0   1    Fayth       Paddock    fpaddock0@nytimes.com           Female
# 1   2    Ogden       Ander      oander1@w3.org                  Female
# 2   3    Ludovico    Defew      ldefew2@github.io               Male
# 3   4    Ambrosius   Menlow     amenlow3@weather.com            Male
# 4   5    Inglebert   Barrasse   ibarrasse4@soup.io              Male
# .. ..          ...        ...                  ...               ...
# 61  89   Catina      Butte      cbutte2g@goo.gl                 Mle
# 62  97   Huntington  Sherrocks  hsherrocks2o@jalbum.net         ale
# 63  99   Hamnet      Rowbotham  hrowbotham2q@timesonline.co.uk  Female
# 64  100  Derrick     Lunge      dlunge2r@ovh.net                e
# 65  101  Mellisa     Dils       mdils2s@google.com.br           Female
#
#          ip_address emp_join_date     emp_country R001_RFLAG R002_RFLAG  \
# 0   95.152.83.222    2020/09/15    China
# 1   79.153.96.224    2020/10/15    United States
# 2   44.72.101.250    2020/05/23    Peru
# 3   66.138.160.23    2021/04/11    China
# 4   180.85.153.228   2020/08/03    Indonesia
# ..             ...          ...          ...      ..         ..
# 61  191.67.160.27    2020/05/20    Portugal
# 62  94.186.119.255   2019/12/16    Bangladesh
# 63  121.121.36       2021/01/19    Ethiopia
# 64  204.134.255      2021/01/23    Indonesia
# 65  198.149.175.144  2021/04/04    Czech Republic
#
#    R003_RFLAG R004_RFLAG emp_sor_id
# 0                         EMP_1
# 1                         EMP_2
# 2                         EMP_3
# 3                         EMP_4
# 4                         EMP_5
# .. ..         ..            ...
# 61  SOFT_R003             EMP_89
# 62  SOFT_R003             EMP_97
# 63                        EMP_99
# 64  SOFT_R003             EMP_100
# 65                        EMP_101
#
# [66 rows x 13 columns]

# %%
passed_records.write.option("header",True).format("csv").mode("overwrite").save(DQSucc)

# %% [markdown]
# # Compute Audit Logs

# %%
# Src Counts
src_count = src_data.count()
# Target Record Counts
target_count = passed_records.count()
# Reject Records Count(Records that have failed atleast one Hard Rule and 0 or more soft rules)
reject_fail_count = error_reject_records.count()
# Soft Fail Record Counts(Records that have failed atleast one Soft Rule but no Hard Rule)
soft_fail_only_count = rulesinglecol.filter((col("ruleflag").contains("HARD") == False) & (col("ruleflag").contains("SOFT") == True)).count()
# Hard Fail Record Counts(Records that have failed atleast one Hard Rule but no Soft Rule)
hard_fail_only_count = rulesinglecol.filter((col("ruleflag").contains("HARD") == True) & (col("ruleflag").contains("SOFT") == False)).count()
# Total Fail Record Counts
total_fail_count = reject_fail_count + soft_fail_only_count
# End Time for Job
end_time = str(datetime.datetime.now())
# Create DQ Dictionary for DQ Log metadata and convert it to Dataframe
audit_log_dic = {"SourceRecCount" : src_count,"TargetRecCount" : target_count,"RejectFailRecCount" : reject_fail_count,"SoftFailOnlyRecCount" : soft_fail_only_count,"HardFailOnlyRecCount" : hard_fail_only_count,"TotalFailRecCount" : total_fail_count,"StartTime" : start_time,"EndTime" :  end_time}

# %%
audit_log_df = spark.createDataFrame([audit_log_dic]).select("SourceRecCount","TargetRecCount","RejectFailRecCount","SoftFailOnlyRecCount","HardFailOnlyRecCount","TotalFailRecCount","StartTime","EndTime")
# Out:
# D:\Programs\Spark\spark-2.4.3-bin-hadoop2.7\python\pyspark\sql\session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
audit_log_df.write.format("avro").mode("append").save(AuditLogs)

# %% [markdown]
# # Compute DQ Logs

# %%
dqlog = rulesinglecol.select("id",explode(split("ruleflag",",")).alias("CATEGORY_RULEID")).filter(trim(col("CATEGORY_RULEID")) != "").withColumn("RULEONLY",split("CATEGORY_RULEID","_").getItem(1))
dqlog_with_det = dqlog.join(dq_rule_bible,dqlog.RULEONLY == dq_rule_bible.RULE_ID).select("id","CATEGORY_RULEID","PRIORITY","DESCRIPTION","OUTPUT_COL")
dqlog_pandas = dqlog_with_det.toPandas()
dqlog_pandas
# Out:
#      id CATEGORY_RULEID PRIORITY  \
# 0   51   SOFT_R001       1
# 1   51   HARD_R002       2
# 2   51   SOFT_R003       3
# 3   51   HARD_R004       4
# 4   52   SOFT_R001       1
# ..  ..         ...      ..
# 79  96   HARD_R002       2
# 80  96   HARD_R004       4
# 81  97   SOFT_R003       3
# 82  98   HARD_R004       4
# 83  100  SOFT_R003       3
#
#                                                                                                                                                                                                                                        DESCRIPTION  \
# 0   Trims Employee IP address and Soft Fail Record in case of invalid IP else it’s a PASS.The trimmed input column is returned as modified column value in case of PASS else return Original Value
# 1   Trims Emp Join Date and Reject/Hard Fail in case date is not in YYYY/MM/DD format else it’s a pass.The trimmed input column is returned as modified column value in case of PASS else return original value
# 2   Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.
# 3   Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value
# 4   Trims Employee IP address and Soft Fail Record in case of invalid IP else it’s a PASS.The trimmed input column is returned as modified column value in case of PASS else return Original Value
# ..                                                                                                                                                                                             ...
# 79  Trims Emp Join Date and Reject/Hard Fail in case date is not in YYYY/MM/DD format else it’s a pass.The trimmed input column is returned as modified column value in case of PASS else return original value
# 80  Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value
# 81  Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.
# 82  Trims Employee Mail and Rejects/Hard Fail record in case of Invalid email else it’s a PASS.The trimmed Input Column is returned as Modifid column value in case of PASS else return Original Value
# 83  Trims Employee Gender and Soft Fail record in case of Invalid Gender else it’s a PASS if values are (m/f/male/female).The trimmed input column is returned as modified column value in case of PASS as Male/Female else return Original Value.
#
#        OUTPUT_COL
# 0   ip_address
# 1   emp_join_date
# 2   gender
# 3   email
# 4   ip_address
# ..         ...
# 79  emp_join_date
# 80  email
# 81  gender
# 82  email
# 83  gender
#
# [84 rows x 5 columns]

# %%
dqlog_with_det.write.option("header",True).format("csv").mode("overwrite").save(DQLogs)
